# %% [markdown]
# ### Types of Operator
#
# Python language supports the following types of operators.
#
#   -  Arithmetic Operators
#   - Comparison (Relational) Operators
#   -  Assignment Operators
#   - Logical Operators
#   - Bitwise Operators
#   - Membership Operators
#   - Identity Operators

# %% [markdown]
# ### Arithmetic Operators
# Operator 	Description 	Example
# + Addition 	Adds values on either side of the operator. 	a + b = 30
# - Subtraction 	Subtracts right hand operand from left hand operand. 	a – b = -10
# * Multiplication 	Multiplies values on either side of the operator 	a * b = 200
# - / Division 	Divides left hand operand by right hand operand 	b / a = 2
# - % Modulus 	Divides left hand operand by right hand operand and returns remainder 	b % a = 0
# - ** Exponent 	Performs exponential (power) calculation on operators 	a**b =10 to the power 20
# - // 	Floor Division - The division of operands where the result is the quotient in which the digits after the decimal point are removed. But if one of the operands is negative, the result is floored, i.e., rounded away from zero (towards negative infinity) − 	9//2 = 4 and 9.0//2.0 = 4.0, -11//3 = -4, -11.0//3 = -4.0

# %% [markdown]
# ![image.png](attachment:59305fc0-63d0-40b7-9935-3badac8e5d69.png)

# %%
x=40
y=5

# %%
z=x+y # arithmetic operator + add
print(f"The answer is {z}")
# Out:
# The answer is 45

# %%
z=x-y # arithmetic operator -  sub
print(f"The answer is {z}")
# Out:
# The answer is 35

# %%
z=x*y # arithmetic operator *  mul
print(f"The answer is {z}")
# Out:
# The answer is 200

# %%
z=x/y # arithmetic operator / div
print(f"The answer is {z}")
# Out:
# The answer is 8.0

# %%
z=x//y # arithmetic operator // int div or floor div
print(f"The answer is {z}")
# Out:
# The answer is 8

# %%
z=x%y # arithmetic operator %  reminder operator
print(f"The answer is {z}")
# Out:
# The answer is 0

# %%
z=x**y # arithmetic operator ** exponsial
print(f"The answer is {z}")
# Out:
# The answer is 102400000

# %%
z=-x+y # arithmetic operator with unary minus 
print(f"The answer is {z}")
# Out:
# The answer is -35

# %%
x1=+45
print(x1)
# Out:
# 45

# %% [markdown]
# # Other than numric data

# %%
# str data
str1="Python"
str2="programming"

# %%
print(str1*4)     # multiplication operator act as an repter of
# Out:
# PythonPythonPythonPython

# %%
print(str1+str2) # + act as str concatenation
# Out:
# Pythonprogramming

# %%
# list data
list1=[1,2,3]
list2=[5,6,7]

# %%
print(list1+list2)  # + act as concatenation
# Out:
# [1, 2, 3, 5, 6, 7]

# %%
print(list1*3)  # * act as repeat of list items in n times  # list*n
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
#tuple data
t1=(1,2,3)
t2=(5,6,7)

# %%
print(t1+t2) # + act as concatenation
# Out:
# (1, 2, 3, 5, 6, 7)

# %%
print(t1*2) # * act as repeat of list items in n times  # tuple*n
# Out:
# (1, 2, 3, 1, 2, 3)

# %% [markdown]
# # Relational /Comparison Operator

# %% [markdown]
# ![image.png](attachment:c0b587fd-ea95-4063-8e6b-193c2f250958.png)

# %%
3>4
# Out:
# False

# %%
x=142
y=75

# %%
if(x<y):
    print("The Comparision is True")
else:
    print("The Comparision is False")
# Out:
# The Comparision is False

# %%
if(x>y):
    print("The Comparision is True")
else:
    print("The Comparision is False")
# Out:
# The Comparision is True

# %%
x=42
y=42
if(x==y):
    print("The Comparision is True")
else:
    print("The Comparision is False")
# Out:
# The Comparision is True

# %%
x=42
y=42
if(x!=y):
    print("The Comparision is True")
else:
    print("The Comparision is False")
# Out:
# The Comparision is False

# %% [markdown]
# ## Python Assignment Operators  =
#
# ### Component Assignment Operators a+=3   ==> a=a+3
# - +=
# - -=
# - *=
# - /=
# - %=
# - //=
# - **=

# %% [markdown]
# ![image.png](attachment:95b2bbd2-9c03-4d26-a006-327ab9e46a32.png)

# %%
x=40

# %%
x*=2
x
# Out:
# 80

# %%
#Example:

# %%
num1 = 4
num2 = 5
res = num1 + num2
res += num1
print(("Line 1 - Result of + is ", res))
# Out:
# ('Line 1 - Result of + is ', 13)

# %% [markdown]
# ### Logical Operator
# - and , or, not

# %% [markdown]
# ![image.png](attachment:e4c94377-8741-42b7-8990-504612b872f2.png)

# %%
a=True
b=True
print(a and b)
# Out:
# True

# %%
a=True
b=False
print(a or b)
# Out:
# True

# %%
print(not b)
# Out:
# True

# %%
age=int(input("Enter Your age"))
citizen=input("enter your citizen country code")
if (age>18 and citizen=="IND"):
    print("He/She is Eligible for Vote")
else:
    print("He/She is not Eligible for Vote")
# Out:
# Enter Your age45
# enter your citizen country codeUSA
# He/She is Eligible for Vote

# %%
Example:

# %%
a = True
b = False
print(('a and b is',a and b))
print(('a or b is',a or b))
print(('not a is',not a))
# Out:
# ('a and b is', False)
#
# ('a or b is', True)
#
# ('not a is', False)

# %% [markdown]
# ### Membership Operators
# - in , not in

# %%
str1="Python Programming"
print("Py" in str1)
# Out:
# True

# %%
list1=["a","b",1,2,4]
print('a' in list1)
# Out:
# True

# %%
1 in {"1":"one","jan":1,"apple":"fruits"}
# Out:
# False

# %%
#Example:

# %%
x = 4
y = 8
list = [1, 2, 3, 4, 5 ];
if ( x in list ):
    print("Line 1 - x is available in the given list")
else:
    print("Line 1 - x is not available in the given list")
if ( y  not in list ):
    print("Line 2 - y is not available in the given list")
else:
    print("Line 2 - y is available in the given list")
# Out:
# Line 1 - x is available in the given list
#
# Line 2 - y is not available in the given list

# %% [markdown]
# ### Identity Operators
# - is , is not

# %%
a=12
b=12

# %%
a is c
# Out:
# False

# %%
print(id(a),id(b))
# Out:
# 2836324772496 2836324772496

# %%
c=14

# %%
id(c)
# Out:
# 2836324772496

# %%
a is not c
# Out:
# True

# %%
x = ["apple", "banana"]
y = ["apple", "banana"]

# %%
print(id(x),id(y))
# Out:
# 2836439675584 2836439848128

# %%
x is y
# Out:
# False

# %%
z=x

# %%
print(id(x),id(z))
# Out:
# 2836439675584 2836439675584

# %%
x is z
# Out:
# True

# %%
#Example:

# %%
x = ["apple", "banana"]
y = ["apple", "banana"]
z = x
print(x is not  z)
# returns True because z is the same object as x
print(x is y)
# returns False because x is not the same object as y, even if they have the same content
print(x == y)
# Out:
# False
# False
# True

# %% [markdown]
# ### Bitwise Operators
# - &  ,  | , ~  ,<<,>>, ^

# %%
bin(60)
# Out:
# '0b111100'

# %%
bin(13)
# Out:
# '0b1101'

# %%
a=60
b=13

# %%
a&b
# Out:
# 12

# %%
a|b
# Out:
# 61

# %%
a^b
# Out:
# 49

# %%
~a
# Out:
# -61

# %%
a<<2   # right shift a*2^n   #n=2
# Out:
# 240

# %%
a>>2  #left shit a/2^n   #3
# Out:
# 15

# %%
Bitwise operator other than numeric

# %%
# set
a={1,2,3,4}
b={3,4,5,6}
print(a&b) # set intersection
# Out:
# {3, 4}

# %%
print(a|b) # set union
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
#Example

# %%
a=60
b=13
print(bin(a),bin(b))
print(a&b)
print(a|b)
print(~a)
print(bin(4),bin(2))
print(4>>2)
print(4<<2)
print(60^13)
# Out:
# 0b111100 0b1101
#
# 12
#
# 61
#
# -61
#
# 0b100 0b10
#
# 1
#
# 16
#
# 49
