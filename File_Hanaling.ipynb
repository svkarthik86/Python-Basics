# %% [markdown]
# # File Handling using Python

# %%
(a) Creating a file
(b) Opening a file
(c) Reading from a file
(d) Writing to a file
(e) Closing a file
Opening a File
A file needs to open before we can perform read and write operations on it.
To open a file, a user needs to fi rst create a fi le object which is associated with a physical fi le. While opening a file, 
a user has to specify the name of the fi le and its mode of operation. The syntax to open a fi le is:
file object = open(File_Name, [Access_Mode],[Buffering])

The above syntax to open a fi le returns the object for fi le name. The mode operation used in the
syntax above is a string value which indicates how a fi le is going to be opened. Table 13.1 describes
the various modes used to open a fi le. The third parameter within the open function is an optional
parameter, which controls the buffering of a fi le. If this parameter is set to 1, line buffering is
performed while accessing the fi le. If the buffering value is set to 0 then no buffering takes place. If
we specify the buffering value as an integer greater than 1 then the buffering action is performed
with the indicated buffer size.

# %% [markdown]
# # Open the file

# %%
file_object = open(File_Name, [Access_Mode],[Buffering])

# %% [markdown]
# ![image.png](attachment:fee69b4e-ceae-4da6-9c6c-72131770c359.png)
# ![image.png](attachment:823d5daf-50ba-4e75-ad72-ce0d46f2f02b.png)

# %% [markdown]
# ![image.png](attachment:68d4530b-bd78-4c5a-ad42-b7ebeff359cd.png)

# %%
file_msg=open("msg.txt")  # default file open

# %%
file_msg  # file object
# Out:
# <_io.TextIOWrapper name='msg.txt' mode='r' encoding='cp1252'>

# %%
#type of file object
print(type(file_msg))
# Out:
# <class '_io.TextIOWrapper'>

# %%
# list the file object
list(file_msg)
# Out:
# ['Hi welcome to python \n', 'file handling programming']

# %%
print(dir(file_msg))
# Out:
# ['_CHUNK_SIZE', '__class__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_checkClosed', '_checkReadable', '_checkSeekable', '_checkWritable', '_finalizing', 'buffer', 'close', 'closed', 'detach', 'encoding', 'errors', 'fileno', 'flush', 'isatty', 'line_buffering', 'mode', 'name', 'newlines', 'read', 'readable', 'readline', 'readlines', 'reconfigure', 'seek', 'seekable', 'tell', 'truncate', 'writable', 'write', 'write_through', 'writelines']

# %%
# view the Mode of the file

# %%
file_msg.mode
# Out:
# 'r'

# %%
#view the file name

# %%
file_msg.name
# Out:
# 'msg.txt'

# %%
# check the file is readable or not

# %%
file_msg=open("msg.txt",'r') 
file_msg.readable()
# Out:
# True

# %%
#chek the file is writable or not # True- writable ,False- not writable

# %%
file_msg=open("msg.txt",'w')  
file_msg.writable()
# Out:
# True

# %%
file_msg=open("msg.txt")  # default file open
for line in file_msg:
    print(line)

# %% [markdown]
# # read() method

# %%
file_msg=open("msg.txt",'r') 
file_msg.read()
# Out:
# 'Hi welcome to python \nfile handling programming'

# %%
file_msg=open("msg.txt",'r') 
file_msg.read(4) # read 4 char
# Out:
# 'Hi w'

# %%
file_msg=open("msg.txt",'r') 
for char in file_msg.read():
        if char=="o":
            print(char)
# Out:
# o
# o
# o
# o

# %% [markdown]
# # readline() method

# %%
file_msg=open("msg.txt",'r') 
file_msg.readline()
# Out:
# 'Hi welcome to python \n'

# %%
file_msg=open("msg.txt",'r') 
for line in file_msg.readline():
    print(line)
# Out:
# H
# i
#
# w
# e
# l
# c
# o
# m
# e
#
# t
# o
#
# p
# y
# t
# h
# o
# n

# %% [markdown]
# # redlines( ) method

# %%
file_msg=open("msg.txt",'r') 
file_msg.readlines()
# Out:
# ['Hi welcome to python \n', 'file handling programming']

# %%
file_msg=open("msg.txt",'r') 
for line in file_msg.readlines():
    print(line)
# Out:
# Hi welcome to python
#
# file handling programming

# %%
mode,name,readable,writable

# %%
list(file_msg)
# Out:
# ['Hi welcome to python \n', 'file handling programming']

# %%
print(dir(file_msg))
# Out:
# ['_CHUNK_SIZE', '__class__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_checkClosed', '_checkReadable', '_checkSeekable', '_checkWritable', '_finalizing', 'buffer', 'close', 'closed', 'detach', 'encoding', 'errors', 'fileno', 'flush', 'isatty', 'line_buffering', 'mode', 'name', 'newlines', 'read', 'readable', 'readline', 'readlines', 'reconfigure', 'seek', 'seekable', 'tell', 'truncate', 'writable', 'write', 'write_through', 'writelines']

# %%
file_msg=open("msg.txt")  # default file open

# %%
file_msg.readline() # readline next line
# Out:
# 'Hi welcome to python \n'

# %%
for line in file_msg.readlines():
    print(line,end='')
# Out:
# file handling programming

# %%
file_msg.close() # close the file # remove file object from memory

# %%
file_msg.readline()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 file_msg.readline()
#
# ValueError: I/O operation on closed file.

# %%
file_msg=open("msg.txt")  # default file open

# %%
file_msg.read(20)
# Out:
# 'lcome to python \nfil'

# %%
f1=open("msg.txt","r") # file open in read mode 
print(f1.readline()) # read one li
print(f1.readline())
print(type(f1.readline()))
f1.close()
# Out:
# Hi welcome to python
#
# file handling programming
# <class 'str'>

# %%
f1=open("msg.txt","r")
list(f1)
# Out:
# ['Hi welcome to python \n', 'file handling programming']

# %% [markdown]
# # Iterating file object using for loop

# %%
f1=open("msg.txt","r")
for line in f1:
    print(line.upper())
# Out:
# HI WELCOME TO PYTHON
#
# FILE HANDLING PROGRAMMING

# %%
f1=open("msg.txt","r")
for char in f1.read():
    if char=="o":
        print(char, end='')
# Out:
# oooo

# %%
f1=open("msg.txt","r")
print(list(f1.read()),end=' ')
# Out:
# ['H', 'i', ' ', 'w', 'e', 'l', 'c', 'o', 'm', 'e', ' ', 't', 'o', ' ', 'p', 'y', 't', 'h', 'o', 'n', ' ', '\n', 'f', 'i', 'l', 'e', ' ', 'h', 'a', 'n', 'd', 'l', 'i', 'n', 'g', ' ', 'p', 'r', 'o', 'g', 'r', 'a', 'm', 'm', 'i', 'n', 'g']

# %%
f1=open("msg.txt","r")
print(f1.read())
# Out:
# Hi welcome to python
# file handling programming

# %%
f1=open("file.txt","r")  
print(f1.readline())
print(f1.readlines())  # all lines as list 
f1.close()
# Out:
# this is file example
#
# 7

# %%
f1=open("file.txt","r")  
print(f1.readline())
print(f1.readline())
print("...................")
# print(f1.readlines())  # all lines as list 
print(f1.read())
f1.close()
# Out:
# this is file example
#
# (a) Creating a file
#
# ...................
# (b) Opening a file
# (c) Reading from a file
# (d) Writing to a file
# (e) Closing a file
# 324
# 45646

# %% [markdown]
# # file Write

# %%
f1=open("demofile.txt","w") # if file already exists, it will truncate and write new contents, else it will create file as in file name
f1.write("check the content trucated or not")
f1.close()

# %%
#file open using With clause  # no need to close the file # automatically it will close

# %%
with open("file2.txt","w+") as f2: # Write and read
    f2.write("(a) Creating a file\n(b) Opening a file\n(c)Reading from a file\n(d)Writing to a file\n(e)Closing a file")
    f2.seek(0)
    data=f2.read()
    print(data)
# Out:
# (a) Creating a file
# (b) Opening a file
# (c)Reading from a file
# (d)Writing to a file
# (e)Closing a file

# %%
# file open with append and read

# %%
with open("file2.txt","a+") as f2: # Write and read
    f2.write("\n(a) Creating a file\n(b) Opening a file\n(c)Reading from a file\n(d)Writing to a file\n(e)Closing a file")
    f2.seek(0)
    data=f2.read()
    print(data)
# Out:
# (a) Creating a file
# (b) Opening a file
# (c)Reading from a file
# (d)Writing to a file
# (e)Closing a file
# (a) Creating a file
# (b) Opening a file
# (c)Reading from a file
# (d)Writing to a file
# (e)Closing a file

# %%
f=open("file.txt","r")
content=f.read()
print(content)
f.close()
# Out:
# (a) Creating a file
# (b) Opening a file
# (c) Reading from a file
# (d) Writing to a file
# (e) Closing a file

# %%
f=open("file.txt","r")
content=f.readline()
print(content)
f.close()
# Out:
# (a) Creating a file

# %%
f=open("file.txt","r")
content=f.readlines()
print(content)
f.close()
# Out:
# ['(a) Creating a file\n', '(b) Opening a file\n', '(c) Reading from a file\n', '(d) Writing to a file\n', '(e) Closing a file']

# %% [markdown]
# ### THE seek() FUNCTION
# - the seek() method is used to set the fi le pointer to a specifi c position in a file.
# - The syntax for seek() function is:   file_object.seek( offset, whence)
# - where offset indicates the number of bytes to be moved from the current position of the pointer and whence indicates the point of reference from where the bytes are to be moved from. The value of whence can be determined from Table 13.3.
# - ![image.png](attachment:76e338c5-7710-4141-b87f-fb6937feb469.png)

# %%
with open("Grades.txt","w+") as gd:
    n=int(input("Enter the number of student:"))
    gd.write(str(n)+"\n")
    for i in range(n):
        gd.write(input()+"\n")
    gd.seek(0)
    print(gd.read())

# %% [markdown]
# Enter the number of student:5
# 60 70 80 90 100
# 55 65 75 58 60
# 70 60 80 90 67
# 89 76 56 43 90
# 67 89 76 54 90

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
with open("Grades.txt","r") as gf:
    n=int(gf.readline())
    for i in range(n):
            grade=list(map(int,gf.readline().split()))
            total=sum(grade)
            percentage=total/len(grade)
            print(f"The Student:{i+1} The Total is:{total} and Percentage is:{percentage}")
# Out:
# The Student:1 The Total is:400 and Percentage is:80.0
# The Student:2 The Total is:340 and Percentage is:68.0
# The Student:3 The Total is:367 and Percentage is:73.4
# The Student:4 The Total is:354 and Percentage is:70.8
# The Student:5 The Total is:376 and Percentage is:75.2

# %%
list(map(int,"60 70 80 90 100".split()))
# Out:
# [60, 70, 80, 90, 100]

# %% [markdown]
# Question:
# Write a program to read the contents of a file Grades.txt and calculate the total marks and
# percentage obtained by a student.
# Output:
# The student:1 The Total is:400 and Percentage is:80.0
# The student:2 The Total is:313 and Percentage is:62.6
# The student:3 The Total is:367 and Percentage is:73.4
# The student:4 The Total is:354 and Percentage is:70.8
# The student:5 The Total is:376 and Percentage is:75.2

# %%
with open("Grades.txt","w+") as grade_file:
    n=input("Enter the Number Students:")
    grade_file.write(n+"\n")
    for _ in range(int(n)):
        grade_file.write(input()+"\n")
    grade_file.seek(0) # move cursor into first position on the file
    print(grade_file.read())
# Out:
# Enter the Number Students:5
# 60 70 80 90 100
# 55 65 75 85 60
# 70 60 80 90 67
# 89 76 56 43 90
# 67 89 76 54 90
# 5
# 60 70 80 90 100
# 55 65 75 85 60
# 70 60 80 90 67
# 89 76 56 43 90
# 67 89 76 54 90

# %%
with open("Grades.txt","r") as gfile:
    gfile.seek(0)
    n=int(gfile.readline())
    for i in range(n):
        grade=list(map(int,gfile.readline().split()))
        total=sum(grade)
        percentage=total/len(grade)
        print(f"The student:{(i+1)} The Total is:{total} and Percentage is:{percentage}")
# Out:
# The student:1 The Total is:400 and Percentage is:80.0
# The student:2 The Total is:313 and Percentage is:62.6
# The student:3 The Total is:367 and Percentage is:73.4
# The student:4 The Total is:354 and Percentage is:70.8
# The student:5 The Total is:376 and Percentage is:75.2

# %%
with open(r"D:\Edubridge\Assignment\StdASS\Lab\Grade.txt","r") as f:
    no_subj=int(f.readline())
    std1_mark=[int(i) for i in f.readline().split()]
    std2_mark=[int(i) for i in f.readline().split()]
    std3_mark=[int(i) for i in f.readline().split()]
    std4_mark=[int(i) for i in f.readline().split()]
    std5_mark=[int(i) for i in f.readline().split()]
    print("Total Marks of std1",sum(std1_mark)," \t"+"The Percentage of std1:",(sum(std1_mark)/500)*100)
    print("Total Marks of std2", sum(std2_mark), " \t" + "The Percentage of std2:", (sum(std2_mark) / 500) * 100)
    print("Total Marks of std3", sum(std3_mark), " \t" + "The Percentage of std1:", (sum(std3_mark) / 500) * 100)
    print("Total Marks of std4",sum(std4_mark)," \t"+"The Percentage of std1:",(sum(std4_mark)/500)*100)
    print("Total Marks of std5",sum(std5_mark)," \t"+"The Percentage of std1:",(sum(std5_mark)/500)*100)
# Out:
# Total Marks of std1 400  	The Percentage of std1: 80.0
# Total Marks of std2 340  	The Percentage of std2: 68.0
# Total Marks of std3 397  	The Percentage of std1: 79.4
# Total Marks of std4 354  	The Percentage of std1: 70.8
# Total Marks of std5 376  	The Percentage of std1: 75.2

# %%
with open(r"D:\Edubridge\Assignment\StdASS\Lab\printfile.txt","a+") as f:
    for i in range(10):
        f.write(f"Line {i} \n")
    print(f.read())

# %%
n=raw_input()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [100], in <cell line: 1>()
# ----> 1 n=raw_input()
#
# NameError: name 'raw_input' is not defined

# %% [markdown]
# # Read multiple .txt file and concatenate into single file

# %%
os.getcwd() # current working directory
# Out:
# 'C:\\Users\\karthick'

# %%
import os
print(os.listdir())
# Out:
# ['.anaconda', '.astropy', '.conda', '.condarc', '.continuum', '.idlerc', '.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '.spyder-py3', '.virtualenvs', 'anaconda3', 'AppData', 'Application Data', 'ArithModule.py', 'arithModule1.py', 'Buit-in-Function.ipynb', 'Contacts', 'Cookies', 'Data.py', 'Data_Type_Conversion_ipynb_txt-checkpoint.ipynb', 'Data_Type_Conversion_ipynb_txt.ipynb', 'DecisionMaking-Test.ipynb', 'DecisionMaking.ipynb', 'demofile.txt', 'Desktop', 'Documents', 'Downloads', 'Favorites', 'file.txt', 'file2.txt', 'File_Hanaling.ipynb', 'Function-MCQ.ipynb', 'Function-old.ipynb', 'Function.ipynb', 'Grades.txt', 'Links', 'Local Settings', 'Loop-checkpoint.ipynb', 'Loop.ipynb', 'Mathpack', 'Modules and Package.ipynb', 'Modules-Batch-2.ipynb', 'msg.txt', 'Music', 'My Documents', 'NetHood', 'ntuser.dat', 'ntuser.dat.log1', 'ntuser.dat.log2', 'NTUSER.DAT{1c2b59c2-c5f5-11eb-bacb-000d3a96488e}.TM.blf', 'NTUSER.DAT{1c2b59c2-c5f5-11eb-bacb-000d3a96488e}.TMContainer0000000
# ...

# %%
for file in os.listdir():
    if file.endswith(".txt"):
            print(file)
# Out:
# demofile.txt
# file.txt
# file2.txt
# Grades.txt
# msg.txt
# output.txt
# Poll.txt

# %%
[file for file in os.listdir() if file.endswith(".txt")] # list comphrence
# Out:
# ['demofile.txt',
#  'file.txt',
#  'file2.txt',
#  'Grades.txt',
#  'msg.txt',
#  'output.txt',
#  'Poll.txt']

# %%
with open("final.txt","w+") as final_file:
    #read all the .txt file names available in current workig directory
    files=[file for file in os.listdir() if file.endswith(".txt")]
    for file in files:
        with open(file) as input_file:
            conent=input_file.read()
            final_file.write(conent)
    final_file.seek(0)
    print(final_file.read())
# Out:
# check the content trucated or notwrite to the file
#   second line data
#  third line dataThe fourth line data
#   fifth line data
#  six line data
# The fourth line data
# fifth line data
# six line data(a) Creating a file
# (b) Opening a file
# (c)Reading from a file
# (d)Writing to a file
# (e)Closing a file
# (a) Creating a file
# (b) Opening a file
# (c)Reading from a file
# (d)Writing to a file
# (e)Closing a file5
# 60 70 80 90 100
# 55 65 75 85 60
# 70 60 80 90 67
# 89 76 56 43 90
# 67 89 76 54 90
# Hi welcome to python
# file handling programming#create database AWSDemo2;
# show databases;
# create table students(StdRegno int,StdFirstName varchar(255),StdLastName varchar(255),StdAdd varchar(255))
# use awsdemo
# insert into students values(1002,"raj","kiran","chennai");The unsupervised learning problems can be grouped as _______.
# A. Clustering
# B.Association
# C.Both A and B
# D.None of the above
# 2.Features of Machine Learning are______.
# A. Automation
# ...

# %%
# reading multiple .txt files in current working directory and concatenate to one single file
"E:\Edubridge\Ticket.txt"

# %%
[file for file in os.listdir(path) if file.endswith(".txt")]
# Out:
# ['DB cmd.txt', 'ML MCQ5.txt', 'output.txt', 'Ticket.txt']

# %%
import os
path=r"E:\\Edubridge"
with open(path+"\\"+"output.txt",'w+') as outputfile:
    files=[file for file in os.listdir(path) if file.endswith(".txt")]
    for file in files:
        with open(path+"\\"+ file) as inputfile:
            content=inputfile.read()
            outputfile.write(content)
    outputfile.seek(0)
    print(outputfile.read())
# Out:
# #create database AWSDemo2;
# show databases;
# create table students(StdRegno int,StdFirstName varchar(255),StdLastName varchar(255),StdAdd varchar(255))
# use awsdemo
# insert into students values(1002,"raj","kiran","chennai");The unsupervised learning problems can be grouped as _______.
# A. Clustering
# B.Association
# C.Both A and B
# D.None of the above
# 2.Features of Machine Learning are______.
# A. Automation
# B.Improved customer experience
# C.Business intelligence
# D.All of the above
# 3.What is the Elbow method?
# a.a way of assessing the fit of a machine learning algorithm
# b.a method used to determine the optimal number of clusters in unsupervised learning, for example K-mean clustering
# c.an approach to estimating â€˜black-boxâ€™ predictions in supervised learning
# d.a method of forecasting in machine learning
# 4.Which of the following is TRUE about over-fitting in machine learning?
# ...

# %%
#rename the file 
import os
os.rename("untitled.txt","NewName.txt")

# %%
print([file for file in os.listdir() if file.endswith(".txt")])
# Out:
# ['demofile.txt', 'file.txt', 'file2.txt', 'Grades.txt', 'msg.txt', 'NewName.txt', 'output.txt', 'Poll.txt']

# %%
n=raw_input("enter")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [52], in <cell line: 1>()
# ----> 1 n=raw_input("enter")
#
# NameError: name 'raw_input' is not defined

# %%
print(os.listdir())
# Out:
# ['.anaconda', '.astropy', '.conda', '.condarc', '.continuum', '.idlerc', '.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '.spyder-py3', '.virtualenvs', 'anaconda3', 'AppData', 'Application Data', 'ArithModule.py', 'arithModule1.py', 'Buit-in-Function.ipynb', 'Contacts', 'Cookies', 'Data.py', 'Data_Type_Conversion_ipynb_txt-checkpoint.ipynb', 'Data_Type_Conversion_ipynb_txt.ipynb', 'DecisionMaking.ipynb', 'demofile.txt', 'Desktop', 'Documents', 'Downloads', 'Favorites', 'file.txt', 'file2.txt', 'File_Hanaling.ipynb', 'Function-MCQ.ipynb', 'Function-old.ipynb', 'Function.ipynb', 'Grades.txt', 'Links', 'Local Settings', 'Loop-checkpoint.ipynb', 'Loop.ipynb', 'Mathpack', 'Modules and Package.ipynb', 'Modules-Batch-2.ipynb', 'msg.txt', 'Music', 'My Documents', 'NetHood', 'NewName.txt', 'ntuser.dat', 'ntuser.dat.log1', 'ntuser.dat.log2', 'NTUSER.DAT{1c2b59c2-c5f5-11eb-bacb-000d3a96488e}.TM.blf', 'NTUSER.DAT{1c2b59c2-c5f5-11eb-bacb-000d3a96488e}.TMContainer00000000000000000001.
# ...

# %%
import os
os.rmdir("Test")

# %%
print(os.listdir())
# Out:
# ['.anaconda', '.astropy', '.conda', '.condarc', '.continuum', '.idlerc', '.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '.spyder-py3', '.virtualenvs', 'anaconda3', 'AppData', 'Application Data', 'ArithModule.py', 'arithModule1.py', 'Buit-in-Function.ipynb', 'Contacts', 'Cookies', 'Data.py', 'Data_Type_Conversion_ipynb_txt-checkpoint.ipynb', 'Data_Type_Conversion_ipynb_txt.ipynb', 'DecisionMaking.ipynb', 'demofile.txt', 'Desktop', 'Documents', 'Downloads', 'Favorites', 'file.txt', 'file2.txt', 'File_Hanaling.ipynb', 'Function-MCQ.ipynb', 'Function-old.ipynb', 'Function.ipynb', 'Grades.txt', 'Links', 'Local Settings', 'Loop-checkpoint.ipynb', 'Loop.ipynb', 'Mathpack', 'Modules and Package.ipynb', 'Modules-Batch-2.ipynb', 'msg.txt', 'Music', 'My Documents', 'NetHood', 'ntuser.dat', 'ntuser.dat.log1', 'ntuser.dat.log2', 'NTUSER.DAT{1c2b59c2-c5f5-11eb-bacb-000d3a96488e}.TM.blf', 'NTUSER.DAT{1c2b59c2-c5f5-11eb-bacb-000d3a96488e}.TMContainer00000000000000000001.regtrans-ms', '
# ...

# %%
os.remove("NewName.txt")
