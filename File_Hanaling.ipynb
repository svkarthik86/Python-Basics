# %%
(a) Creating a file
(b) Opening a file
(c) Reading from a file
(d) Writing to a file
(e) Closing a file
Opening a File
A fi le needs to open before we can perform read and write operations on it. To open a fi le, a user
needs to fi rst create a fi le object which is associated with a physical fi le. While opening a fi le, a user
has to specify the name of the fi le and its mode of operation. The syntax to open a fi le is:
file object = open(File_Name, [Access_Mode],[Buffering])
The above syntax to open a fi le returns the object for fi le name. The mode operation used in the
syntax above is a string value which indicates how a fi le is going to be opened. Table 13.1 describes
the various modes used to open a fi le. The third parameter within the open function is an optional
parameter, which controls the buffering of a fi le. If this parameter is set to 1, line buffering is
performed while accessing the fi le. If the buffering value is set to 0 then no buffering takes place. If
we specify the buffering value as an integer greater than 1 then the buffering action is performed
with the indicated buffer size.
# Out:
#   File "C:\Users\karthik\AppData\Local\Temp/ipykernel_19920/3111025183.py", line 1
#     (a) Creating a fi le
#         ^
# SyntaxError: invalid syntax

# %%
file object = open(File_Name, [Access_Mode],[Buffering])

# %% [markdown]
# ![image.png](attachment:fee69b4e-ceae-4da6-9c6c-72131770c359.png)
# ![image.png](attachment:823d5daf-50ba-4e75-ad72-ce0d46f2f02b.png)

# %% [markdown]
# ![image.png](attachment:68d4530b-bd78-4c5a-ad42-b7ebeff359cd.png)

# %%
f1=open("file.txt","r") # file open in read mode 
print(f1.readline()) # read one li
print(f1.readline())
print(type(f1.readline()))
f1.close()
# Out:
# elpmaxe elif si siht
# (a) creating a file
#
# <class 'str'>

# %%
f1=open("file.txt","r")  
print(f1.readline())
print(f1.readlines())  # all lines as list 
f1.close()
# Out:
# this is file example
#
# 7

# %%
f1=open("file.txt","r")  
print(f1.readline())
print(f1.readline())
print("...................")
# print(f1.readlines())  # all lines as list 
print(f1.read())
f1.close()
# Out:
# this is file example
#
# (a) Creating a file
#
# ...................
# (b) Opening a file
# (c) Reading from a file
# (d) Writing to a file
# (e) Closing a file
# 324
# 45646

# %%
f1=open("demofile.txt","w")
f1.write("Tterdgfdg")
f1.close()

# %%
f=open("file.txt","r")
content=f.read()
print(content)
f.close()
# Out:
# (a) Creating a file
# (b) Opening a file
# (c) Reading from a file
# (d) Writing to a file
# (e) Closing a file

# %%
f=open("file.txt","r")
content=f.readline()
print(content)
f.close()
# Out:
# (a) Creating a file

# %%
f=open("file.txt","r")
content=f.readlines()
print(content)
f.close()
# Out:
# ['(a) Creating a file\n', '(b) Opening a file\n', '(c) Reading from a file\n', '(d) Writing to a file\n', '(e) Closing a file']

# %%
f=open("file.txt","r")
content=f.readlines()
for i in content:
    print(i)
f.close()
# Out:
# (a) Creating a file
#
# (b) Opening a file
#
# (c) Reading from a file
#
# (d) Writing to a file
#
# (e) Closing a file

# %%
f=open("file.txt","r")
for line in f:
    print(line)
f.close()
# Out:
# (a) Creating a file
#
# (b) Opening a file
#
# (c) Reading from a file
#
# (d) Writing to a file
#
# (e) Closing a file

# %%
x=open("file.txt","w")
x.write("write to the file\n")

x.close()

# %% [markdown]
# ### THE seek() FUNCTION
# - the seek() method is used to set the fi le pointer to a specifi c position in a file.
# - The syntax for seek() function is:   file_object.seek( offset, whence)
# - where offset indicates the number of bytes to be moved from the current position of the pointer and whence indicates the point of reference from where the bytes are to be moved from. The value of whence can be determined from Table 13.3.
# - ![image.png](attachment:76e338c5-7710-4141-b87f-fb6937feb469.png)

# %%
with open(r"D:\Edubridge\Assignment\StdASS\Lab\Grade.txt","r") as f:
    no_subj=int(f.readline())
    std1_mark=[int(i) for i in f.readline().split()]
    std2_mark=[int(i) for i in f.readline().split()]
    std3_mark=[int(i) for i in f.readline().split()]
    std4_mark=[int(i) for i in f.readline().split()]
    std5_mark=[int(i) for i in f.readline().split()]
    print("Total Marks of std1",sum(std1_mark)," \t"+"The Percentage of std1:",(sum(std1_mark)/500)*100)
    print("Total Marks of std2", sum(std2_mark), " \t" + "The Percentage of std2:", (sum(std2_mark) / 500) * 100)
    print("Total Marks of std3", sum(std3_mark), " \t" + "The Percentage of std1:", (sum(std3_mark) / 500) * 100)
    print("Total Marks of std4",sum(std4_mark)," \t"+"The Percentage of std1:",(sum(std4_mark)/500)*100)
    print("Total Marks of std5",sum(std5_mark)," \t"+"The Percentage of std1:",(sum(std5_mark)/500)*100)
# Out:
# Total Marks of std1 400  	The Percentage of std1: 80.0
# Total Marks of std2 340  	The Percentage of std2: 68.0
# Total Marks of std3 397  	The Percentage of std1: 79.4
# Total Marks of std4 354  	The Percentage of std1: 70.8
# Total Marks of std5 376  	The Percentage of std1: 75.2

# %%
with open(r"D:\Edubridge\Assignment\StdASS\Lab\printfile.txt","a+") as f:
    for i in range(10):
        f.write(f"Line {i} \n")
    print(f.read())
