# %% [markdown]
# ### Welcome Programming

# %%
name=input("What is your name?")
print("Welcome "+ name)
# Out:
# What is your name? f
# Welcome f

# %% [markdown]
# ## Python Overview

# %% [markdown]
# Python indentation is a way of telling a Python interpreter that the group of statements belongs to a particular block of code

# %% [markdown]
# ![image.png](attachment:b30ee9b5-3d1c-4d0f-9fa3-c9d1cc8838e9.png)

# %% [markdown]
# #### In Python Everything is an Object:

# %% [markdown]
# ![image.png](attachment:6c4ec444-42f0-44eb-bcf4-a20f57033f39.png)

# %%
"KARTHIK".lower()
# Out:
# 'karthik'

# %%
Fname=input("Enter your Fname:") #get First name from user
Lname=input("Enter your Lname:") #get Last name from the user
print("Hello {} {},Welcome to Python Programming".format(Fname,Lname))
# Out:
# Enter your Fname: sai
# Enter your Lname: kiran
# Hello sai kiran,Welcome to Python Programming

# %%
Fname=input("Enter your Fname:") #get First name from user
Lname=input("Enter your Lname:") #get Last name from the user
print("Hello {1} {0},Welcome to Python Programming".format(Fname,Lname))
# Out:
# Enter your Fname: sai
# Enter your Lname: kiran
# Hello kiran sai,Welcome to Python Programming

# %%
type(Fname)
# Out:
# str

# %%
Lname
# Out:
# 'kiran'

# %%
## Python Built-in Data Types
- Numeric Types: int, float, complex 
- Text Sequence Type: str
- Sequence Types: list, tuple, range
- Mapping Types: dict
- Set Types: set, frozenset
- Binary Sequence Types:bytes, bytearray, memoryview

# %% [markdown]
# ### Python Identifier:
# An identifier is a name given to entities like class, functions, variables, etc. It helps to differentiate one entity from another.
# Rules for writing identifiers
# - Identifiers can be a combination of letters in lowercase (a to z) or uppercase (A to Z) or digits (0 to 9) or an underscore _.
# - Names like myClass, var_1 and print_this_to_screen, all are valid example.
# - An identifier cannot start with a digit. 1variable is invalid, but variable1 is a valid name.
# - Keywords cannot be used as identifiers.
# - Example:
# ```python
# num=10 #variable,
# def getdata(): #function,
# class Students: #class ...etc
# ```
# #### Here are naming conventions for Python identifiers:
# - Class names start with an uppercase letter. All other identifiers start with a lowercase letter.
# - Starting an identifier with a single leading underscore indicates that the identifier is private.
# - Starting an identifier with two leading underscores indicates a strongly private identifier.
# - If the identifier also ends with two trailing underscores, the identifier is a language-defined special name.

# %% [markdown]
# ### Reserved Words(Python Keyword)

# %%
import keyword as kw
print(kw.kwlist)
print("------------------------------------------------")
print("Number of Keywords in Python is:",len(kw.kwlist))
# Out:
# ['False', 'None', 'True', '__peg_parser__', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# ------------------------------------------------
# Number of Keywords in Python is: 36

# %% [markdown]
# ### Python Variable
# - Variables are  reserved memory locations to store values.  it reserve some space in memory.
# - Variable is assign the value using "=" assignment operator

# %%
#Numeric type

# %%
x=15

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
y=10.35

# %%
print(type(y))
# Out:
# <class 'float'>

# %%
z=3+4j

# %%
print(type(z))
# Out:
# <class 'complex'>

# %%
print(id(x))
# Out:
# 2076418140912

# %%
x=20

# %%
x
# Out:
# 20

# %%
print(id(x))
# Out:
# 2076418141072

# %%
x=10  
y=55.6 
# x and y are varaiable 
print(x)
print(y) 
# Multiple value assignment
d=e=f=40 # all d,e,f varibles are assigned the same value
a,b,c=5,10,15# diffrent variable with diffrent value
print(a,b,c,d,e,f)
# Out:
# 10
# 55.6
# 5 10 15 40 40 40

# %% [markdown]
# ## Python Built-in Data Types
# - Numeric Types: int, float, complex
# - Text Sequence Type: str
# - Sequence Types: list, tuple, range
# - Mapping Types: dict
# - Set Types: set, frozenset
# - Binary Sequence Types:bytes, bytearray, memoryview

# %% [markdown]
# ### Numeric Types: int, float, complex
# -

# %%
# Numeric Types: int, float, complex
x=10 # variable x assigned by integer type data
y=2.6783 #varaiable y assigned by float type data
z=3+8j #varaiable z assigned by complex type data
print("Type of x is: {} and Value is: {}".format(type(x),x))
print("Type of y is: {} and Value is: {}".format(type(y),y))
print("Type of z is: {} and Value is: {}".format(type(z),z))
# Out:
# Type of x is: <class 'int'> and Value is: 10
# Type of y is: <class 'float'> and Value is: 2.6783
# Type of z is: <class 'complex'> and Value is: (3+8j)

# %%
print(type(x))
# Out:
# <class 'int'>

# %% [markdown]
# #### Text Sequence Type: str
# - A String is a sequence of Unicode characters. In Python, String is called str.
# - Strings are represented by using Double quotes " "  or single quotes ' '.
# - If the strings are multiple, then it can be denoted by the use of triple quotes “”” or ”’.
# - All the characters between the quotes are items of the string.
# - str is immutable type, str object can't modifiable

# %%
string1="this is String"

# %%
print(string1)
# Out:
# this is String

# %%
print(type(string1))
# Out:
# <class 'str'>

# %%
str1="Python Programming by EduBridge" # variable str1 assigned by string type data
str2='Data Analytics' 
str3="123" 
print("Type of str1 is: {} and Value is: {}".format(type(str1),str1))
print("Type of str2 is: {} and Value is: {}".format(type(str2),str2))
print("Type of str3 is: {} and Value is: {}".format(type(str3),str3))
# Out:
# Type of str1 is: <class 'str'> and Value is: Python Programming by EduBridge
# Type of str2 is: <class 'str'> and Value is: Data Analytics
# Type of str3 is: <class 'str'> and Value is: 123

# %% [raw]
# String is immutable object

# %%
s1="python"

# %%
print(s1)
# Out:
# python

# %%
print("the type {} and id {} is".format(type(s1),id(s1)))
# Out:
# the type <class 'str'> and id 2076460905136 is

# %%
s1="java"

# %%
print("the type {} and id {} is".format(type(s1),id(s1)))
# Out:
# the type <class 'str'> and id 2076424078512 is

# %%
# index and Slicing

# %%
print(s1[0])  # positive index
# Out:
# p

# %%
print(s1[-1]) #negative index
# Out:
# n

# %%
print(s1[0:4]) #slicing operator :
# Out:
# pyth

# %%
print(s1[-4:-1])
# Out:
# tho

# %%
print(s1[::-1])  # reverse the string uing slicing operator
# Out:
# nohtyp

# %% [markdown]
# ### Sequence Types: list, tuple, range

# %% [markdown]
# ### List
# - An ordered sequence of items and collection of diffrent data type
# -List is mutable type, it can modifiable
# - The list is enclosed with brackets and commas are used to separate the items
#   list=[1,2,3,"a","b","c"]

# %%
l1=[1,2,3,"apple","orange","banana",3.53,6.8,5+7j,['a','b','c']]   # list l1

# %%
print(l1)
# Out:
# [1, 2, 3, 'apple', 'orange', 'banana', 3.53, 6.8, (5+7j), ['a', 'b', 'c']]

# %%
print(type(l1))
# Out:
# <class 'list'>

# %% [markdown]
# ## Index in List

# %%
l1[4]    # 4th index element in list l1
# Out:
# 'orange'

# %%
l1[-1] # last element in the list l1
# Out:
# ['a', 'b', 'c']

# %% [markdown]
# ## Slice Operation in List  #[start:end:step]

# %%
fruits=l1[3:6]      # slice the l1 list elements from index 3 to 6-1
print(fruits)
# Out:
# ['apple', 'orange', 'banana']

# %%
even_data=l1[::2]
print(even_data)
# Out:
# [1, 3, 'orange', 3.53, (5+7j)]

# %%
reverse_list=l1[::-1]    # reverse the list elements
print(reverse_list)
# Out:
# [['a', 'b', 'c'], (5+7j), 6.8, 3.53, 'banana', 'orange', 'apple', 3, 2, 1]

# %% [markdown]
# ## List is mutable object

# %%
l1
# Out:
# [1, 2, 3, 'apple', 'orange', 'banana', 3.53, 6.8, (5+7j), ['a', 'b', 'c']]

# %%
l1[-1]="mango"  # modify last element as Mango

# %%
print(l1)
# Out:
# [1, 2, 3, 'apple', 'orange', 'banana', 3.53, 6.8, (5+7j), 'mango']

# %%
l1.insert(4,"jackfruit")

# %%
print(l1)
# Out:
# [1, 2, 3, 'apple', 'jackfruit', 'orange', 'banana', 3.53, 6.8, (5+7j), 'mango']

# %% [markdown]
# # List copy and list Alias

# %%
list2=[1,2,3]

# %%
list3=list2   #  assign only object reference from list2 to list3 # both are pointing same memory location

# %%
print(list3)
# Out:
# [1, 2, 3]

# %%
list3[0]="abc"

# %%
print(list3)
# Out:
# ['abc', 2, 3]

# %%
print(list2)
# Out:
# ['abc', 2, 3]

# %% [markdown]
# ## Copy only data without list alias problem

# %%
l2=[4,5,6]
l3=l2[:]      #  slicing operator copy only the value / copy()
print(l3)
# Out:
# [4, 5, 6]

# %%
l3[0]=100
print(l3)
print(l2)
# Out:
# [100, 5, 6]
# [4, 5, 6]

# %% [markdown]
# ## Operators in List

# %%
print(l3)
print(l2)
# Out:
# [100, 5, 6]
# [4, 5, 6]

# %%
print(l3+l2)  # concatenation of two list using + operator
# Out:
# [100, 5, 6, 4, 5, 6]

# %%
print(l3*3)    # repet  3 times
# Out:
# [100, 5, 6, 100, 5, 6, 100, 5, 6]

# %% [markdown]
# # Tuple

# %%
tuple1=(1, 2, 3,("a","b","c"),'apple', 'orange', 'banana', 3.53, 6.8, (5+7j), ['a', 'b', 'c'])

# %%
print(tuple1)
# Out:
# (1, 2, 3, ('a', 'b', 'c'), 'apple', 'orange', 'banana', 3.53, 6.8, (5+7j), ['a', 'b', 'c'])

# %%
print(type(tuple1))
# Out:
# <class 'tuple'>

# %%
t1=2,3,5   # comma seperated value is also tuple

# %%
print(type(t1))
# Out:
# <class 'tuple'>

# %% [markdown]
# ## Index in Tuple

# %%
print(tuple1)
# Out:
# (1, 2, 3, ('a', 'b', 'c'), 'apple', 'orange', 'banana', 3.53, 6.8, (5+7j), ['a', 'b', 'c'])

# %%
tuple1[4]  # return 4th index element
# Out:
# 'apple'

# %%
tuple1[-8]   #return -8th index element
# Out:
# ('a', 'b', 'c')

# %% [markdown]
# ## Slicing in Tuple

# %%
tuple1[4:7]   # slice index value from 4 to 7-1
# Out:
# ('apple', 'orange', 'banana')

# %%
tuple1[-11:-7]
# Out:
# (1, 2, 3, ('a', 'b', 'c'))

# %% [markdown]
# # Tuple is Immutable Object

# %%
print(tuple1)
# Out:
# (1, 2, 3, ('a', 'b', 'c'), 'apple', 'orange', 'banana', 3.53, 6.8, (5+7j), ['a', 'b', 'c'])

# %%
tuple1[4]="JackFruit"   # immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_556/1900454614.py in <module>
# ----> 1 tuple1[4]="JackFruit"
#
# TypeError: 'tuple' object does not support item assignment

# %%
print(tuple1+(1,2))
# Out:
# (1, 2, 3, ('a', 'b', 'c'), 'apple', 'orange', 'banana', 3.53, 6.8, (5+7j), ['a', 'b', 'c'], 1, 2)

# %%
t2=(1,2,3)
t3=(6,7,8)

# %%
t2+t3  # concatenate the tuple t2 and t3
# Out:
# (1, 2, 3, 6, 7, 8)

# %%
t2*3   # rept  3 times the tuple
# Out:
# (1, 2, 3, 1, 2, 3, 1, 2, 3)

# %% [markdown]
# # Dictionary in  python

# %%
month_dict={"jan":1,"feb":2,"march":3,3:"three"}

# %%
print(month_dict)
# Out:
# {'jan': 1, 'feb': 2, 'march': 3, 3: 'three'}

# %%
print(type(month_dict))
# Out:
# <class 'dict'>

# %% [markdown]
# ## Index in Dictionary

# %%
month_dict[3]    # key is index
# Out:
# 'three'

# %%
month_dict["march"]
# Out:
# 3

# %%
#for dict  slicing is not possible , it is unordered

# %% [markdown]
# ## Dict is mutable

# %%
month_dict["April"]=4   # if index not in dict, it will add the key and value

# %%
month_dict
# Out:
# {'jan': 1, 'feb': 2, 'march': 3, 3: 'three', 'April': 4}

# %%
month_dict["April"]="Four"  # if index is already there it will overwrite

# %%
month_dict
# Out:
# {'jan': 1, 'feb': 2, 'march': 3, 3: 'three', 'April': 'Four'}

# %% [markdown]
# ## View the Dict Elements

# %%
month_dict.keys() # return dict keys in list form
# Out:
# dict_keys(['jan', 'feb', 'march', 3, 'April'])

# %%
month_dict.values()# return dict values in list form
# Out:
# dict_values([1, 2, 3, 'three', 'Four'])

# %%
month_dict.items() # return dict key,Value pair tuple in List form
# Out:
# dict_items([('jan', 1), ('feb', 2), ('march', 3), (3, 'three'), ('April', 'Four')])

# %% [markdown]
# # Set

# %%
set1={"a","b",1,3,3.4,(5,6)}

# %%
print(set1)
# Out:
# {'a', 'b', 3, 3.4, 1, (5, 6)}

# %%
print(type(set1))
# Out:
# <class 'set'>

# %%
s2={1,2,3,[5,6]}  # set,list,dict are mutable , this cant be an element of the set
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_556/2666789961.py in <module>
# ----> 1 s2={1,2,3,[5,6]}  # set,list,dict are mutable , this cant be an element of the set
#
# TypeError: unhashable type: 'list'

# %%
s3={1,2,2,3,3,4} # set is  distinct

# %%
print(s3)
# Out:
# {1, 2, 3, 4}

# %%
# set is unorder ther is no index and slice operation

# %% [markdown]
# # Set is mutable

# %%
set1
# Out:
# {(5, 6), 1, 3, 3.4, 'a', 'b'}

# %%
set1.add(100)  # add value 100 to set1

# %%
print(set1)
# Out:
# {'a', 'b', 3, 3.4, 1, (5, 6), 100}

# %% [markdown]
# # Set Operations

# %%
A={1,2,3,4}
B={3,4,5,6}

# %%
#set difference
print(A-B)
# Out:
# {1, 2}

# %%
print(B-A)
# Out:
# {5, 6}

# %%
A.difference(B) # A-B
# Out:
# {1, 2}

# %%
#intersection
print(A&B)
# Out:
# {3, 4}

# %%
A|B  # union
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# # Frozenset

# %%
A
# Out:
# {1, 2, 3, 4}

# %%
f_set=frozenset(A)

# %%
print(f_set)
# Out:
# frozenset({1, 2, 3, 4})

# %%
print(type(f_set))
# Out:
# <class 'frozenset'>

# %% [markdown]
# # Frozenset is immutable

# %%
f_set.add(100)  # it cant modify the elements
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_556/2649308338.py in <module>
# ----> 1 f_set.add(100)
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %% [markdown]
# ## Frozenset Opereation

# %%
f_set_A=frozenset(A)
f_set_B=frozenset(B)

# %%
f_set_A-f_set_B # set difference
# Out:
# frozenset({1, 2})

# %%
f_set_A&f_set_B   # intersection
# Out:
# frozenset({3, 4})

# %%
f_set_A|f_set_B # uninon
# Out:
# frozenset({1, 2, 3, 4, 5, 6})

# %% [markdown]
# # Boolean

# %%
b1=True

# %%
print(type(b1))
# Out:
# <class 'bool'>

# %%
b2=False

# %%
bool(23)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool({})
# Out:
# False

# %%
bool('')
# Out:
# False

# %%
bool(None)
# Out:
# False

# %%
bool((2,3))
# Out:
# True

# %%
bool(-23)
# Out:
# True

# %%
print(l1)
# Out:
# [1, 2, 3, 'apple', 'orange', 'banana', 3.53, 6.8, (5+7j), ['a', 'b', 'c']]

# %%
print(type(l1))  # type of l1 variable
# Out:
# <class 'list'>

# %%
indexing operation on List

# %%
print(l1[0])
# Out:
# 1

# %%
print(l1[-1])
# Out:
# ['a', 'b', 'c']

# %%
print(l1[8])
# Out:
# (5+7j)

# %%
Slicing operation on List

# %%
print(l1[0:5])     # [start:end:step]   default step is one , strat index is included and end is excluded (n-1)
# Out:
# [1, 2, 3, 'apple', 'orange']

# %%
print(l1[0:6:2])
# Out:
# [1, 3, 'orange']

# %%
print(l1[::2])
# Out:
# [1, 3, 'orange', 3.53, (5+7j)]

# %%
print(l1[::-1])  # reverse the list elements
# Out:
# [['a', 'b', 'c'], (5+7j), 6.8, 3.53, 'banana', 'orange', 'apple', 3, 2, 1]

# %% [markdown]
# ## List is Mutable object

# %%
l2=[45,69,12,"a","b","c"]

# %%
l2[-1]=50

# %%
print(l2)
# Out:
# [45, 69, 12, 'a', 'b', 50]

# %%
print("the type of l2 is{} and memory addr of l2 list {}".format(type(l2),id(l2)))
# Out:
# the type of l2 is<class 'list'> and memory addr of l2 list 2076535179264

# %%
l2=["jan","feb","march"]

# %%
print(l2)
# Out:
# ['jan', 'feb', 'march']

# %%
print("the type of l2 is{} and memory addr of l2 list {}".format(type(l2),id(l2)))
# Out:
# the type of l2 is<class 'list'> and memory addr of l2 list 2076536602432

# %%
l3=l2  # list alliasing

# %%
print("the type of l3 is{} and memory addr of l3 list {}".format(type(l3),id(l3)))
# Out:
# the type of l3 is<class 'list'> and memory addr of l3 list 2076536602432

# %%
print(l3)
# Out:
# ['jan', 'feb', 'march']

# %%
print(l2)
# Out:
# ['jan', 'feb', 'march']

# %%
l3[0]='Dec'

# %%
print(l2)
# Out:
# ['Dec', 'feb', 'march']

# %%
#copy the List element and avoid list aliasing

# %%
l3=l2[:]  # it will copy only elementwise  # it will avoid list aliasing problem

# %%
l3=l2.copy()  # it will also copy only the element in list # it will avoid list aliasing problem

# %%
Example1:

# %%
list1=[1,2,3,"a","b","c"]    # mixed data type
print(list1[0])
print(list1[-1])
print(list1[3:5])
list1[0]=45   # list mutable
print(list1)
# Out:
# 1
# c
# ['a', 'b']
# [45, 2, 3, 'a', 'b', 'c']

# %%
Example2:

# %%
a,b,c="jan","feb","march"

# %%
l4=[a,b,c]

# %%
print(l4)
# Out:
# ['jan', 'feb', 'march']

# %% [markdown]
# # Tuple (immutable object)

# %%
t1=(1,2,3,"apple","orange","banana",3.53,6.8,5+7j,['a','b','c'])

# %%
print(t1)
# Out:
# (1, 2, 3, 'apple', 'orange', 'banana', 3.53, 6.8, (5+7j), ['a', 'b', 'c'])

# %%
print(type(t1))
# Out:
# <class 'tuple'>

# %% [raw]
# Tuple is immutable object

# %%
t1[0]=10    # Tuple is immutable object
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11076/3039031863.py in <module>
# ----> 1 t1[0]=10
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# indexing for Tuple

# %%
print(t1[5])
# Out:
# banana

# %%
Slicing

# %%
print(t1[0:5])
# Out:
# (1, 2, 3, 'apple', 'orange')

# %%
print(t1[::-1])  #reverse the tuple data
# Out:
# (['a', 'b', 'c'], (5+7j), 6.8, 3.53, 'banana', 'orange', 'apple', 3, 2, 1)

# %%
tup1=(1,2,3,"a","b","c")   
print(tup1[0])
tup1[2]=34  # tuple immmutable
# Out:
# 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11076/1618742784.py in <module>
#       1 tup1=(1,2,3,"a","b","c")
#       2 print(tup1[0])
# ----> 3 tup1[2]=34  # tuple immmutable
#
# TypeError: 'tuple' object does not support item assignment

# %%
dic1={1:"a",2:"b",3:"c"}  # mapping data type , Unorder
print(dic1[3])  #  3 is key it is used as index
dic1[4]="d" # added,   dict is mutable 
print(dic1)
# Out:
# c
# {1: 'a', 2: 'b', 3: 'c', 4: 'd'}

# %%
set1={1,2,3,3,3,4,5,5,6} # remove duplicate element 
set1.add(8)# set is mutable 
set2=frozenset(set1) # frozen set is immutable 
set2.add(10)
print(set2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16848/2881079975.py in <module>
#       2 set1.add(8)
#       3 set2=frozenset(set1)
# ----> 4 set2.add(10)
#       5 print(set2)   # set is mutable
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
# boolean Type   False/ True 
b1= 10                  #  []  {}  () ""   bool willbe False
print(bool(b1))
b2=True
print(type(b2))
# Out:
# True
# <class 'bool'>

# %%
x=binary(4)
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16848/383108900.py in <module>
# ----> 1 x=binary(4)
#       2 print(x)
#
# NameError: name 'binary' is not defined

# %%
x = b"Hello" 
print(x)
y = bytearray(5)
print(y)
z = memoryview(bytes(5))
print(z)
# Out:
# b'Hello'
# bytearray(b'\x00\x00\x00\x00\x00')
# ...

# %%
#range(start,stop,step)
print(range(10))
for i in range(10,20,2):
    print(i)
# Out:
# range(0, 10)
# 10
# 12
# 14
# 16
# 18

# %%
a=[1,20,30,40]
print(a)
del a[1:3]  # object a is deleted 
print(a)
# Out:
# [1, 20, 30, 40]
# [1, 40]
